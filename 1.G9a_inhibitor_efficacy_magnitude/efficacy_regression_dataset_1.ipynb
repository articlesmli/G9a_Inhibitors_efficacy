# %% [markdown]
# # ML regression to predict the Efficacy of an active G9a inhibitor

# %% [markdown]
# ### Content   <a name="content"></a>

# %% [markdown]
# 1. [Load data](#1)
# 2. [Regression Machine Learning](#2)
# 3. [Cros-validation](#3)
# 4. [Calculate the relative error of the Gradient Boosting Regressor model](#4)
# 5. [Feature importance of the Gradient Boosting Regressor model](#5)
# 6. [Comparison of the first six features from the feature importance results](#6)
# 7. [Hyperparameter tuning of the model with the reduced features](#7)
# 8. [Relative error of the reduced data model](#8)

# %% [markdown]
# ## Load data<a name="1"></a>

# %%
# pip install modin[ray] 
# pip install sidetable

# %%
import pandas as pd 

# # loading the dataset for the regression ML
df = pd.read_csv('data_reg_basic.csv', index_col=[0])
# Avoid some columns to be truncated during df display
pd.set_option('display.max_columns', None)
# Display the data frame
print('Shape of df: ', df.shape)
df.head()
# Out:
# Shape of df:  (26790, 64)
#          CID       SID  Efficacy  \
# 0  135915053  56319965  163.3340
# 1  135915052  56318992  109.5210
# 2  135900543  51086642   98.1573
# 3  135900540  51086515  146.9800
# 4  135897134  56318894  163.0410
#
#                                               SMILES     MW             MF  \
# 0  CCCN1C(=CC(=C1C)C2=CSC(=N2)NC(=O)CCC3=NC4=CC=C...  435.5    C23H25N5O2S
# 1  CCCC1=CC(=O)NC(=N1)SCC(=O)N(CCOC)C2=C(N(C(=O)N...  500.6    C23H28N6O5S
# 2  C1=CC(=CC=C1NC(=O)CSC2=NC(=C(C(=O)N2)NC(=O)C3=...  449.4  C19H14F3N5O3S
# 3  CC(=O)NC1=CC=C(C=C1)NC(=O)CSC2=NC(=C(C(=O)N2)N...  512.5    C23H24N6O6S
# 4  CC(C)CN(C1=C(N(C(=O)NC1=O)CC2=CC=CC=C2)N)C(=O)...  502.6     C27H30N6O4
#
#     TPSA   XL  HAC  HBDC  HBAC  RBC  CBUC     MMX6      MMX       SX6  \
# 0  117.0  2.8   31     2     5    7     1  17.8694  17.8694  0.082314
# 1  172.0  0.8   35     3     8   11     1  14.0287  14.0287  0.075508
# 2  151.0  2.0   31     4     9    6     1   6.5161   6.5161 -0.159177
# 3  199.0  0.8   36     5     9    9     1  20.5259  21.5663 -0.049764
# 4  137.0  1.8   37     3     6    9     1  12.9638  12.9638  0.575062
#
#          SX     MMY6      MMY       SY6        SY   Volume_1  Volume_2  \
# 0 -0.034893  10.8275  12.0275 -0.087487 -0.173883   0.195432  0.001865
# 1  0.076284  14.2560  15.4560 -0.022511 -0.013702   0.195432  0.000699
# 2 -0.104719  18.7500  21.1500  0.088285  0.143002  12.507661  0.037176
# 3 -0.087331  14.1034  14.1034  0.128934  0.200037   0.083006  0.000517
# 4  0.532346  16.5215  17.7215  0.346460  0.176789   0.195432  0.003433
#
#    MMX6_3D   MMX_3D    SX6_3D     SX_3D  MMY6_3D   MMY_3D    SY6_3D     SY_3D  \
# 0  17.5340  19.3722  0.172632  0.282350   6.6305   8.0824 -0.427647 -0.154356
# 1  10.2185  12.2236  0.629553  0.386651   6.0154   7.8840  0.149252  0.288979
# 2  11.0932  13.3081  0.335645  0.467170   6.4155   8.2934 -0.448524 -0.690856
# 3  11.5600  13.5814  0.346999  0.432999  10.3972  12.0706 -0.449562 -0.541443
# 4   9.9702  11.1871  0.252543  0.277778   9.2767  10.4937 -0.090845  0.111323
#
#    MMZ6_3D  MMZ_3D    SZ6_3D     SZ_3D  Volume_1_3D  XY_3D_volume  \
# 0   3.5023  5.6490  0.488571  0.292375    32.824767      0.010407
# 1   6.9525  8.3908  0.974558  0.550393    29.040476      0.170102
# 2   2.4547  5.5169 -0.139042 -0.422588   162.225931      0.211769
# 3   2.8515  5.5493 -0.382651 -0.272418    83.276709      0.082873
# 4   4.5327  6.8431  0.168788  0.318390    11.707530      0.002110
#
#    XZ_3D_volume  YZ_3D_volume  C_relative  H_relative  O_relative  S_relative  \
# 0      0.190597      0.098098        0.41        0.45        0.04        0.02
# 1      0.382104      0.119195        0.37        0.44        0.08        0.02
# 2      1.251976      1.686218        0.42        0.31        0.07        0.02
# 3      0.223200      0.225223        0.38        0.40        0.10        0.02
# 4      0.040380      0.026634        0.40        0.45        0.06        0.00
#
#    N_relative  Br_relative  Cl_relative  F_relative      C     H      O     S  \
# 0        0.09          0.0          0.0        0.00  63.43  5.79   7.35  7.36
# 1        0.10          0.0          0.0        0.00  55.19  5.64  15.98  6.40
# 2        0.11          0.0          0.0        0.07  50.78  3.14  10.68  7.13
# 3        0.10          0.0          0.0        0.00  53.90  4.72  18.73  6.26
# 4        0.09          0.0          0.0        0.00  64.53  6.02  12.73  0.00
#
#        N   Br   Cl      F  C_rel_2D  allAtoms_rel_2D  C_rel_XY_3D  \
# 0  16.08  0.0  0.0   0.00  1.650372         1.485712     2.644446
# 1  16.79  0.0  0.0   0.00  0.984056         0.907654     1.698723
# 2  15.58  0.0  0.0  12.68  0.347525         0.308090     1.729125
# 3  16.40  0.0  0.0   0.00  1.455387         1.529156     1.111838
# 4  16.72  0.0  0.0   0.00  0.784662         0.731529     1.074757
#
#    allAtoms_rel_XY_3D  C_rel_XZ_3D  allAtoms_rel_XZ_3D  C_rel_YZ_3D  \
# 0            2.396838     5.006424            3.429315     1.893184
# 1            1.550431     1.469759            1.456786     0.865214
# 2            1.604662     4.519167            2.412242     2.613558
# 3            1.125164     4.054007            2.447408     3.646221
# 4            1.066078     2.199616            1.634800     2.046617
#
#    allAtoms_rel_YZ_3D  Similarity
# 0            1.430767       0.052
# 1            0.939601       0.054
# 2            1.503272       0.049
# 3            2.175157       0.052
# 4            1.533472       0.059

# %%
# Check for NaN
df.isnull().values.any()
# Out:
# False

# %%
df.describe(include="all")
# Out:
#                  CID           SID      Efficacy  \
# count   2.679000e+04  2.679000e+04  26790.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean    1.091874e+07  2.602193e+07    130.902124
# std     2.615565e+07  1.671974e+07     30.207705
# min     2.370000e+02  8.421340e+05     43.577100
# 25%     1.480231e+06  1.474506e+07    109.234750
# 50%     3.237418e+06  2.478575e+07    129.762000
# 75%     6.899892e+06  2.673066e+07    149.690500
# max     1.359151e+08  9.034183e+07    299.718000
#
#                                                    SMILES            MW  \
# count                                               26790  26790.000000
# unique                                              26790           NaN
# top     CCCN1C(=CC(=C1C)C2=CSC(=N2)NC(=O)CCC3=NC4=CC=C...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    362.219342
# std                                                   NaN     79.512256
# min                                                   NaN     82.100000
# 25%                                                   NaN    305.400000
# 50%                                                   NaN    359.400000
# 75%                                                   NaN    416.900000
# max                                                   NaN    821.900000
#
#                  MF          TPSA            XL           HAC          HBDC  \
# count         26790  26790.000000  26790.000000  26790.000000  26790.000000
# unique        15265           NaN           NaN           NaN           NaN
# top     C18H17N3O2S           NaN           NaN           NaN           NaN
# freq             25           NaN           NaN           NaN           NaN
# mean            NaN     91.129613      3.103576     25.184248      1.273647
# std             NaN     34.758588      1.293311      5.612410      0.972059
# min             NaN      0.000000     -8.200000      6.000000      0.000000
# 25%             NaN     67.900000      2.300000     21.000000      1.000000
# 50%             NaN     88.200000      3.200000     25.000000      1.000000
# 75%             NaN    112.000000      3.900000     29.000000      2.000000
# max             NaN    340.000000      8.200000     50.000000     13.000000
#
#                 HBAC           RBC     CBUC          MMX6           MMX  \
# count   26790.000000  26790.000000  26790.0  26790.000000  26790.000000
# unique           NaN           NaN      NaN           NaN           NaN
# top              NaN           NaN      NaN           NaN           NaN
# freq             NaN           NaN      NaN           NaN           NaN
# mean        5.159164      4.772004      1.0     10.820822     11.393794
# std         1.843106      2.258578      0.0      3.614898      3.513774
# min         0.000000      0.000000      1.0      0.714500      1.334900
# 25%         4.000000      3.000000      1.0      8.264300      8.838100
# 50%         5.000000      5.000000      1.0     10.396100     11.178550
# 75%         6.000000      6.000000      1.0     12.994000     13.718525
# max        18.000000     15.000000      1.0     31.938000     31.938000
#
#                  SX6            SX          MMY6           MMY           SY6  \
# count   26790.000000  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.026397      0.025054      9.346940      9.905757     -0.024719
# std         0.313437      0.289196      3.577346      3.455948      0.381519
# min        -1.557835     -1.175301      0.412500      0.412500     -1.517135
# 25%        -0.173750     -0.164448      6.757800      7.446975     -0.281499
# 50%         0.014301      0.012720      9.133100      9.720100     -0.019787
# 75%         0.223271      0.211232     11.801275     12.011700      0.228826
# max         1.530227      1.224436     31.358000     31.529000      1.633274
#
#                   SY      Volume_1      Volume_2       MMX6_3D        MMX_3D  \
# count   26790.000000  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       -0.007829      6.587725      0.039534     11.341407     13.344028
# std         0.331921     42.901301      0.260756      2.856502      2.796471
# min        -1.214819      0.000000      0.000000      0.975000      3.899900
# 25%        -0.234983      0.000000      0.000002      9.288925     11.317900
# 50%        -0.005670      0.082433      0.000188     11.137600     13.123550
# 75%         0.223174      0.539235      0.003868     13.160800     15.130975
# max         1.483559   2321.338098     13.151876     26.380600     27.670300
#
#               SX6_3D         SX_3D       MMY6_3D        MMY_3D        SY6_3D  \
# count   2.679000e+04  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    4.201479e-03      0.005084      5.613876      7.600966     -0.002127
# std     3.232232e-01      0.288005      1.856924      1.771663      0.460464
# min    -1.465220e+00     -1.114339      0.166000      2.297600     -2.273516
# 25%    -1.976979e-01     -0.186527      4.241625      6.266850     -0.292486
# 50%    -9.395224e-07      0.003506      5.525400      7.476550      0.000020
# 75%     2.051459e-01      0.197531      6.844825      8.760450      0.289904
# max     1.572993e+00      1.059648     13.379300     15.479000      2.127669
#
#                SY_3D       MMZ6_3D        MMZ_3D        SZ6_3D         SZ_3D  \
# count   26790.000000  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       -0.001531      2.957842      4.770969      0.000684     -0.000045
# std         0.331995      1.317354      1.435069      0.569092      0.362880
# min        -1.409802      0.000100      0.000300     -3.597405     -5.387489
# 25%        -0.206794      2.261900      4.041175     -0.284096     -0.173399
# 50%        -0.000017      2.797050      4.741450      0.000678      0.000391
# 75%         0.205278      3.740375      5.638575      0.283911      0.171741
# max         2.122627      9.656900     11.146900      3.854187      5.467601
#
#          Volume_1_3D  XY_3D_volume  XZ_3D_volume  YZ_3D_volume    C_relative  \
# count   2.679000e+04  26790.000000  2.679000e+04  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    6.227197e+01      0.366787  4.965853e-01      0.479950      0.416009
# std     7.712382e+01      1.350007  7.203959e+00      7.110876      0.043870
# min     1.161843e-07      0.000109  2.000274e-07      0.000002      0.130000
# 25%     2.712392e+01      0.050191  4.215651e-02      0.041396      0.390000
# 50%     4.252487e+01      0.124258  1.055183e-01      0.104203      0.420000
# 75%     7.077959e+01      0.314035  2.630848e-01      0.261348      0.440000
# max     3.526947e+03    129.800141  7.597305e+02    777.263945      0.600000
#
#           H_relative    O_relative    S_relative    N_relative   Br_relative  \
# count   26790.000000  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.419357      0.065514      0.017486      0.071291      0.001466
# std         0.060560      0.038843      0.019971      0.035989      0.006874
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.380000      0.040000      0.000000      0.050000      0.000000
# 50%         0.420000      0.060000      0.020000      0.070000      0.000000
# 75%         0.460000      0.090000      0.030000      0.090000      0.000000
# max         0.660000      0.290000      0.230000      0.540000      0.120000
#
#          Cl_relative    F_relative             C             H             O  \
# count   26790.000000  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.004536      0.004057     60.488541      5.221697     12.400523
# std         0.012777      0.015631      8.847334      1.381787      6.928816
# min         0.000000      0.000000     15.500000      0.000000      0.000000
# 25%         0.000000      0.000000     54.800000      4.270000      7.610000
# 50%         0.000000      0.000000     60.830000      5.150000     12.240000
# 75%         0.000000      0.000000     66.650000      6.100000     16.820000
# max         0.250000      0.350000     90.850000     13.190000     54.190000
#
#                    S             N            Br            Cl             F  \
# count   26790.000000  26790.000000  26790.000000  26790.000000  26790.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        6.311274     11.842106      1.106977      1.703862      0.922828
# std         6.758371      5.544879      4.920089      4.525238      3.299506
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      8.090000      0.000000      0.000000      0.000000
# 50%         6.980000     11.370000      0.000000      0.000000      0.000000
# 75%        10.170000     14.850000      0.000000      0.000000      0.000000
# max        53.950000     57.500000     60.090000     46.970000     63.940000
#
#             C_rel_2D  allAtoms_rel_2D   C_rel_XY_3D  allAtoms_rel_XY_3D  \
# count   26790.000000     26790.000000  26790.000000        26790.000000
# unique           NaN              NaN           NaN                 NaN
# top              NaN              NaN           NaN                 NaN
# freq             NaN              NaN           NaN                 NaN
# mean        1.375404         1.317216      2.269236            1.854651
# std         0.859841         0.699258      1.062891            0.608571
# min         0.152146         0.158514      0.537249            0.752498
# 25%         0.818009         0.830296      1.511822            1.390169
# 50%         1.160260         1.157257      1.997489            1.729193
# 75%         1.704289         1.631291      2.766201            2.196369
# max        25.304933        22.516606     38.598795            7.721405
#
#          C_rel_XZ_3D  allAtoms_rel_XZ_3D   C_rel_YZ_3D  allAtoms_rel_YZ_3D  \
# count   26790.000000        26790.000000  26790.000000        26790.000000
# unique           NaN                 NaN           NaN                 NaN
# top              NaN                 NaN           NaN                 NaN
# freq             NaN                 NaN           NaN                 NaN
# mean       96.800158           29.259810     46.495549           17.401598
# std       899.440646          428.965540    479.208717          284.085023
# min         0.596586            0.908398      0.210874            0.683794
# 25%         2.852956            2.202303      1.433920            1.300653
# 50%         3.913761            2.784937      1.897556            1.564289
# 75%         5.507507            3.571511      2.584801            1.932936
# max     32177.666667        24400.000000  24163.000000        18692.333333
#
#           Similarity
# count   26790.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.056346
# std         0.015052
# min         0.000000
# 25%         0.048000
# 50%         0.054000
# 75%         0.061000
# max         0.678000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26790 entries, 0 to 26789
# Data columns (total 64 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CID                 26790 non-null  int64
#  1   SID                 26790 non-null  int64
#  2   Efficacy            26790 non-null  float64
#  3   SMILES              26790 non-null  object
#  4   MW                  26790 non-null  float64
#  5   MF                  26790 non-null  object
#  6   TPSA                26790 non-null  float64
#  7   XL                  26790 non-null  float64
#  8   HAC                 26790 non-null  int64
#  9   HBDC                26790 non-null  int64
#  10  HBAC                26790 non-null  int64
#  11  RBC                 26790 non-null  int64
#  12  CBUC                26790 non-null  int64
#  13  MMX6                26790 non-null  float64
#  14  MMX                 26790 non-null  float64
#  15  SX6                 26790 non-null  float64
#  16  SX                  26790 non-null  float64
#  17  MMY6                26790 non-null  float64
#  18  MMY                 26790 non-null  float64
#  19  SY6                 26790 non-null  float64
#  20  SY                  26790 non-null  float64
#  21  Volume_1            26790 non-null  float64
#  22  Volume_2            26790 non-null  float64
#  23  MMX6_3D             26790 non-null  float64
#  24  MMX_3D              26790 non-null  float64
#  25  SX6_3D              26790 non-null  float64
#  26  SX_3D               26790 non-null  float64
#  27  MMY6_3D             26790 non-null  float64
#  28  MMY_3D              26790 non-null  float64
#  29  SY6_3D              26790 non-null  float64
#  30  SY_3D               26790 non-null  float64
#  31  MMZ6_3D             26790 non-null  float64
#  32  MMZ_3D              26790 non-null  float64
#  33  SZ6_3D              26790 non-null  float64
#  34  SZ_3D               26790 non-null  float64
#  35  Volume_1_3D         26790 non-null  float64
#  36  XY_3D_volume        26790 non-null  float64
#  37  XZ_3D_volume        26790 non-null  float64
#  38  YZ_3D_volume        26790 non-null  float64
#  39  C_relative          26790 non-null  float64
#  40  H_relative          26790 non-null  float64
#  41  O_relative          26790 non-null  float64
#  42  S_relative          26790 non-null  float64
#  43  N_relative          26790 non-null  float64
#  44  Br_relative         26790 non-null  float64
#  45  Cl_relative         26790 non-null  float64
#  46  F_relative          26790 non-null  float64
#  47  C                   26790 non-null  float64
#  48  H                   26790 non-null  float64
#  49  O                   26790 non-null  float64
#  50  S                   26790 non-null  float64
#  51  N                   26790 non-null  float64
#  52  Br                  26790 non-null  float64
#  53  Cl                  26790 non-null  float64
#  54  F                   26790 non-null  float64
#  55  C_rel_2D            26790 non-null  float64
#  56  allAtoms_rel_2D     26790 non-null  float64
#  57  C_rel_XY_3D         26790 non-null  float64
#  58  allAtoms_rel_XY_3D  26790 non-null  float64
#  59  C_rel_XZ_3D         26790 non-null  float64
#  60  allAtoms_rel_XZ_3D  26790 non-null  float64
#  61  C_rel_YZ_3D         26790 non-null  float64
#  62  allAtoms_rel_YZ_3D  26790 non-null  float64
#  63  Similarity          26790 non-null  float64
# dtypes: float64(55), int64(7), object(2)
# memory usage: 13.3+ MB

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Regression Machine Learning <a name="2"></a>

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Separate the training columns from the target column 'Fit_HillSlope'
X = df.drop(columns=['CID', 'SID', 'SMILES','MF', 'Efficacy']) 
y = df['Efficacy'] 

# Split the data set into train and test parts 
X_train_unscaled, X_test_unscaled, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.20,
                                                    random_state=5) 
# # Standardise the data points
sc = StandardScaler()
X_train = sc.fit_transform(X_train_unscaled)
X_test = sc.transform(X_test_unscaled)

# Print the shape of each part
print("Shapes:")
print("X_train: ", X_train.shape)
print("X_test:  ", X_test.shape)
print("y_train: ", y_train.shape)
print("y_test:  ", y_test.shape)
# Out:
# Shapes:
# X_train:  (21432, 59)
# X_test:   (5358, 59)
# y_train:  (21432,)
# y_test:   (5358,)

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Instantiate the algorithms that will be used, placing them in a dictionary 
regs = {"SVR":SVR(kernel='linear'),
        "DecisionTree":DecisionTreeRegressor(), 
        "RandomForest":RandomForestRegressor(), 
        "GradientBoost":GradientBoostingRegressor(),}

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Create statistics with the results of training with different algorithms
def model_fit(regs):
    fitted_model={}
    model_result = pd.DataFrame()
    for model_name, model in regs.items():
        model.fit(X_train,y_train)
        fitted_model.update({model_name:model})
        model_dict = {}
        model_dict['Algorithm'] = model_name
        model_dict['RMSE_Train'] = round(root_mean_squared_error(y_train, model.predict(X_train)),2)
        model_dict['RMSE_Test'] = round(root_mean_squared_error(y_test, model.predict(X_test)),2)
        model_dict['MAE_Train'] = round(mean_absolute_error(y_train, model.predict(X_train)),2)
        model_dict['MAE_Test'] = round(mean_absolute_error(y_test, model.predict(X_test)),2)
        model_dict['R2_Train'] = round(r2_score(y_train, model.predict(X_train)),2)
        model_dict['R2_Test'] = round(r2_score(y_test, model.predict(X_test)),2)
        model_result = model_result._append(model_dict,ignore_index=True)
    return fitted_model, model_result

fitted_model, model_result = model_fit(regs)
model_result.sort_values(by=['MAE_Test'],ascending=True)
# Out:
#        Algorithm  RMSE_Train  RMSE_Test  MAE_Train  MAE_Test  R2_Train  \
# 2   RandomForest       11.03      29.08       8.63     23.19      0.87
# 3  GradientBoost       28.89      29.29      22.84     23.37      0.09
# 0            SVR       29.88      29.50      23.53     23.55      0.03
# 1   DecisionTree        0.15      42.26       0.00     33.34      1.00
#
#    R2_Test
# 2     0.05
# 3     0.04
# 0     0.03
# 1    -1.00

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Cross-validation <a name="3"></a>

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# Create statistics with the results of cross-validation
def model_CV(regs):
    fitted_model={}
    model_cv_result = pd.DataFrame()
    for model_name, model in regs.items():
        fitted_model.update({model_name:model})
        scores = cross_val_score(model, X_train, y_train, cv=5,
                        scoring=('neg_mean_absolute_error'))
        scores = -scores
        model_dict = {}
        model_dict['Algorithm'] = model_name
        model_dict['CV_MAE'] = round(np.mean(scores), 2)
        model_dict['Sta Dev MAE'] = round(np.std(scores), 2)
        model_dict['List of MAE'] = np.round(scores, 2)
        model_cv_result = model_cv_result._append(model_dict,ignore_index=True)
    return fitted_model, model_cv_result

fitted_model, model_cv_result = model_CV(regs)
model_cv_result.sort_values(by=['CV_MAE'],ascending= True)
# Out:
#        Algorithm  CV_MAE  Sta Dev MAE                          List of MAE
# 2   RandomForest   23.31         0.26  [23.17, 23.27, 23.71, 22.96, 23.46]
# 3  GradientBoost   23.45         0.25  [23.26, 23.37, 23.84, 23.15, 23.66]
# 0            SVR   23.61         0.21   [23.4, 23.63, 23.92, 23.35, 23.75]
# 1   DecisionTree   33.45         0.28  [33.14, 33.21, 33.83, 33.34, 33.76]

# %% [markdown]
# [<a href="#content">Back to top</a>]

# %% [markdown]
# ## Calculate the relative error of the Gradient Boosting Regressor model  <a name="4"></a>

# %%
import sklearn.metrics as metrics
from sklearn.metrics import r2_score

# Instantiate and train a model
model = GradientBoostingRegressor().fit(X_train, y_train)

# Predict 
pred = model.predict(X_test)

# Evaluate
print('Mean Absolute Error (MAE):', round(metrics.mean_absolute_error(y_test, pred),2))
print('Mean Squared Error (MSE):', round(metrics.mean_squared_error(y_test, pred),2))
print('Root Mean Squared Error (RMSE):', round(np.sqrt(metrics.mean_squared_error(y_test, pred))))
print("R2 score for perfect model is:", round(r2_score(y_test, pred), 2))
# Out:
# Mean Absolute Error (MAE): 23.37
# Mean Squared Error (MSE): 858.31
# Root Mean Squared Error (RMSE): 29
# R2 score for perfect model is: 0.04

# %%
# Create a data frame with the test values 
data_verify=pd.DataFrame(y_test.tolist(),columns=["Real Values"])

# Create a data frame with the values predicted 
data_predicted=pd.DataFrame(pred.tolist(),columns=["Predicted Values"])

# Concatenate the data frames with the test and the values predicted
final_output=pd.concat([data_verify,data_predicted],axis=1)

# Create column with the difference between the test and prediction values
final_output["Difference"]= np.abs(final_output["Real Values"]-final_output["Predicted Values"])
final_output["Relative proportion Difference/Real Value"]= (final_output["Difference"]/final_output["Real Values"])

# Display the resulted data frame 
final_output
# Out:
#       Real Values  Predicted Values  Difference  \
# 0         93.9131        129.071853   35.158753
# 1        184.9150        133.314664   51.600336
# 2        134.7190        117.482561   17.236439
# 3        146.6760        135.256592   11.419408
# 4        162.1990        133.000295   29.198705
# ...           ...               ...         ...
# 5353     168.7410        147.710479   21.030521
# 5354     124.2480        134.156776    9.908776
# 5355     148.7570        130.981006   17.775994
# 5356     126.7020        129.386354    2.684354
# 5357     144.2640        131.078666   13.185334
#
#       Relative proportion Difference/Real Value
# 0                                      0.374375
# 1                                      0.279049
# 2                                      0.127944
# 3                                      0.077855
# 4                                      0.180018
# ...                                         ...
# 5353                                   0.124632
# 5354                                   0.079750
# 5355                                   0.119497
# 5356                                   0.021186
# 5357                                   0.091397
#
# [5358 rows x 4 columns]

# %%
# Mean of the relative error
df_reg_rel_mean = final_output["Relative proportion Difference/Real Value"].mean()
print("Relative error: ", df_reg_rel_mean)
# Out:
# Relative error:  0.19218762226144664

# %% [markdown]
# [<a href="#content">Back to top</a>]
